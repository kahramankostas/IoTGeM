# %%
import os
import time
import sklearn
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
from tabulate import tabulate

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.tree import DecisionTreeClassifier

evaluate={'Acc':"Accuracy", 'b_Acc':"Balanced Accuracy", 'F1':"F1 Score", 'kap':"Kappa", 'ROC':"Roc"}

# %%
df=pd.read_csv("x.csv")

# %%
df=df.fillna("0")

# %%
data=df

# %%
unique=[]
D = {} 

    

for i in df["Dataset"].values:
    temp=i
    temp=temp.replace(" ","")
    temp=temp.split(",")
    for j in temp:
        D[j] = D.get(j, 0) + 1
        if j not in unique:
            unique.append(j)

# %%
D
# Out:
# {'Private': 6,
#  'CICIDS2017': 12,
#  'CIDDS-01': 2,
#  'UNSW-NB15': 14,
#  'NSL-KDD': 15,
#  'BoT-IoT': 12,
#  'Edge-IIoTset': 1,
#  'N-BaIoT': 3,
#  'NID': 1,
#  'KDD99': 7,
#  'DS2OS': 3,
#  'IoTID20': 2,
#  'CICIDS2018': 6,
#  'TON_IoT': 5,
#  'MQTTset': 1,
#  'InSDN': 1,
#  'IoTNI': 2,
#  'CICDDoS2019': 2,
#  'AWID': 2,
#  'IoT-23': 2,
#  'MQTT-IoT-IDS2020': 2,
#  'ISCXIDS2012': 1,
#  'IPFlow': 1,
#  'Kitsune': 1}

# %%
D={'Private': 6,
 'CICIDS2017': 12,
 'CIDDS-01': 2,
 'UNSW-NB15': 14,
 'NSL-KDD': 15,
 'BoT-IoT': 12,
 'Edge-IIoTset': 1,
 'N-BaIoT': 3,
 'NID': 1,
 'KDD99': 7,
 'DS2OS': 3,
 'IoTID20': 2,
 'CICIDS2018': 6,
 'TON_IoT': 5,
 'MQTTset': 1,
 'InSDN': 1,
 'IoTNI': 2,
 'CICDDoS2019': 2,
 'AWID': 2,
 'IoT-23': 2,
 'MQTT-IoT-IDS20': 2,
 'ISCXIDS2012': 1,
 'IPFlow': 1,
 'Kitsune': 1}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")
plt.ylabel("Count")
#plt.xlabel("Dataset Names")
plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x
plt.xticks(rotation=90) 
plt.savefig("dataset.pdf",bbox_inches='tight',format="pdf")#, dpi=400)
plt.show()

# %%
'CIDDS-01',
 'DS2OS','MQTTset',
 'N-BaIoT','InSDN',

# %%
sorted(unique)
# Out:
# ['AWID',
#  'BoT-IoT',
#  'CICDDoS2019',
#  'CICIDS2017',
#  'CICIDS2018',
#  'CIDDS-01',
#  'DS2OS',
#  'Edge-IIoTset',
#  'IPFlow',
#  'ISCXIDS2012',
#  'InSDN',
#  'IoT-23',
#  'IoTID20',
#  'IoTNI',
#  'KDD99',
#  'Kitsune',
#  'MQTT-IoT-IDS2020',
#  'MQTTset',
#  'N-BaIoT',
#  'NID',
#  'NSL-KDD',
#  'Private',
#  'TON_IoT',
#  'UNSW-NB15']

# %%
D = {}

# %%
unique=[]
for i in df["ML"].values:
    temp=i
    temp=temp.replace(" ","")
    temp=temp.split(",")
    for j in temp:
        D[j] = D.get(j, 0) + 1
        if j not in unique:
            unique.append(j)

# %%
D={'NB': 23,
 'BN': 3,
 'J48': 1,
 'ZeroR': 1,
 'OneR': 1,
 'LR': 16,
 'SVM': 34,
 'MLP': 28,
 'RF': 42,
 'DT': 28,
 'kNN': 33,
 'CNN': 14,
 'LSTM': 5,
 'RNN': 7,
 'XGB': 12,
 'CB': 6,
 'AB': 4,
 'RB': 1,
 'Bagg': 3,
 'PCA': 3,
 'SET': 1,
 'QDA': 1,
 'DFF': 1,
 'CART': 3,
 'LDA': 3,
 'LGBM': 3,
 'SGD': 2,
 'GB': 4,
 'BT': 1,
 'RFF': 1,
 'ETC': 4,
 'GRU': 1}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")
plt.ylabel("Count")
#plt.xlabel("Machine Learning Algorithms")
plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x
plt.xticks(rotation=90) 
plt.savefig("mls.pdf",bbox_inches='tight',format="pdf")#, dpi=400)
plt.show()

# %%
D = {}

# %%
unique=[]
for i in df["Features"].values:
    temp=i
    temp=temp.replace(" ","")
    temp=temp.split(",")
    for j in temp:
        D[j] = D.get(j, 0) + 1
        if j not in unique:
            unique.append(j)

# %%
D={'Packet': 6,
 'Argus': 26,
 'Flowmeter': 21,
 'NetFlow': 3,
 'Zeek': 16,
 'KDD': 21,
 'Kitsune': 5,
 'DS2OS': 3,
 'Flow(NA)': 1,
 'AWID': 2,
 'Bi-flow': 1,
 'FlowLabeler': 1}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")
plt.ylabel("Count")
#plt.xlabel("Feature Type")
plt.bar(range(len(D)), list(D.values()), align='center')
plt.xticks(range(len(D)), list(D.keys()))
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x
plt.xticks(rotation=90) 
plt.savefig("features.pdf",bbox_inches='tight',format="pdf")#, dpi=400)
plt.show()

# %%
unique=[]
for i in df.values:
    print(i)
# Out:
# ['Anthi2019a' 2019 'Private' 'NB,BN,J48,ZeroR,OneR,LR,SVM,ANN,RF'
#  'Packet ' 287]
# ['Zolanvari2019' 2019 'Private' 'RF,DT,NB,kNN,ANN,SVM,LR' 'Argus' 218]
# ['Roopak2019a' 2019 'CICIDS2017' 'CNN,LSTM,RNN,NB,RF' 'Flowmeter' 212]
# ['Verma2020' 2020 'CIDDS-01,UNSW-NB15,NSL-KDD' 'ANN,XGB,CB,kNN'
#  'NetFlow, Argus,Zeek, KDD' 163]
# ['Jan2019a' 2019 'CICIDS2017' 'ANN,kNN,SVM,' 'Flowmeter' 158]
# ['Churcher2021' 2021 'BoT-IoT' 'kNN,SVM,DT,NB,RF,ANN,LR' 'Argus' 75]
# ['ferrag2022edge,' 2022 'Edge-IIoTset' 'DT,RF,SVM,kNN,ANN' 'Packet ' 42]
# ['abu2022elba,' 2023 'N-BaIoT' 'AB,RB,Bagg' 'Kitsune' 21]
# ['Bagaa2020' 2020 'NSL-KDD' 'SVM' 'KDD' 80]
# ['raghuvanshi2022intrusion,' 2022 'NSL-KDD' 'SVM,RF,LR' 'KDD' 34]
# ['Bhuvaneswari2020' 2020 'BoT-IoT' 'SVM,RNN,LSTM' 'Argus' 60]
# ['mihoub2022denial,' 2022 'BoT-IoT' 'RF,DT,kNN,MLP,RNN,LSTM' 'Argus' 30]
# ['saba2022anomaly,' 2022 'NID,BoT-IoT' 'CNN' 'Argus, KDD' 29]
# ['Roy2022' 2022 'CICIDS2017,NSL-KDD' 'CNN,LSTM,RNN,' 'Flowmeter,KDD' 27]
# ...

# %%
col_names = ["duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate","label"]

# %%
len(col_names)
# Out:
# 42
