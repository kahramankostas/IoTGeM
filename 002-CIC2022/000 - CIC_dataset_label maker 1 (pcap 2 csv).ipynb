# %%
import os
import pandas as pd

# %%
def folder(f_name): #this function creates a folder named "attacks" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
folder("pcaps")

# %%
def find_the_way(path,file_format,con=""):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                if con in file:
                    files_add.append(os.path.join(r, file))  
            
    return files_add

# %%
files_add=find_the_way('./','.pcap')
files_add
# Out:
# ['./1-Flood\\ArloQ Camera\\HTTP\\ArloQCamHTTPFlood_1.pcap',
#  './1-Flood\\ArloQ Camera\\HTTP\\ArloQCamHTTPFlood_2.pcap',
#  './1-Flood\\ArloQ Camera\\HTTP\\ArloQCamHTTPFlood_3.pcap',
#  './1-Flood\\ArloQ Camera\\TCP\\ArloQCamTCPFlood_1.pcap',
#  './1-Flood\\ArloQ Camera\\TCP\\ArloQCamTCPFlood_2.pcap',
#  './1-Flood\\ArloQ Camera\\TCP\\ArloQCamTCPFlood_3.pcap',
#  './1-Flood\\ArloQ Camera\\UDP\\ArloQCamUDPFlood_1.pcap',
#  './1-Flood\\ArloQ Camera\\UDP\\ArloQCamUDPFlood_2.pcap',
#  './1-Flood\\ArloQ Camera\\UDP\\ArloQCamUDPFlood_3.pcap',
#  './1-Flood\\Atomi Coffee Maker\\HTTP\\AtomiCoffeeMakerHTTPFlood_1.pcap',
#  './1-Flood\\Atomi Coffee Maker\\HTTP\\AtomiCoffeeMakerHTTPFlood_2.pcap',
#  './1-Flood\\Atomi Coffee Maker\\HTTP\\AtomiCoffeeMakerHTTPFlood_3.pcap',
#  './1-Flood\\Atomi Coffee Maker\\TCP\\AtomiCoffeeMakerTCPFlood_1.pcap',
#  './1-Flood\\Atomi Coffee Maker\\TCP\\AtomiCoffeeMakerTCPFlood_2.pcap',
#  './1-Flood\\Atomi Coffee Maker\\TCP\\AtomiCoffeeMakerTCPFlood_3.pcap',
#  './1-Flood\\Atomi Coffee Maker\\UDP\\AtomiCoffeeMakerUDPFlood_1.pcap',
#  './1-Flood\\Atomi Coffee Maker\\UDP\\AtomiCoffeeMakerUDPFlood_2.pcap',
#  './1-Flood\\Atomi Coffee Maker\\UDP\\AtomiCoffeeMakerUDPFlood_3.pcap',
#  './1-Flood\\Borun Camera\\UDP\\BorunCamUDPFlood_1.pcap',
#  './1-Flood\\Borun Camera\\UDP\\BorunCamUDPFlood_2.pcap',
#  './1-Flood\\Borun Camera\\UDP\\BorunCamUDPFlood_3.pcap',
#  './1-Flood\\Eufy Home Base\\HTTP\\EufyHomeBaseHTTPFlood_1.pcap',
#  './1-Flood\\Eufy Home Base\\HTTP\\EufyHomeBaseHTTPFlood_2.pcap',
#  './1-Flood\\Eufy Home Base\\HTTP\\EufyHomeBaseHTTPFlood_3.pcap',
#  './1-Flood\\Eufy Home Base\\TCP\\EufyHomeBaseTCPFlood_1.pcap',
#  './1-Flood\\Eufy Home Base\\TCP\\EufyHomeBaseTCPFlood_2.pcap',
#  './1-Flood\\Eufy Home Base\\TCP\\EufyHomeBaseTCPFlood_3.pcap',
#  './1-Flood\\Eufy Home Base\\UDP\\EufyHomeBaseUDPFlood_1.pcap',
#  './1-Flood\\Globe Lamp\\HTTP\\GlobeLampHTTPFlood_1.pcap',
#  './1-Flood\\Globe Lamp\\HTTP\\GlobeLampHTTPFlood_2.pcap',
#  './1-Flood\\Globe Lamp\\HTTP\\GlobeLampHTTPFlood_3.pcap',
#  './1-Flood\\Globe Lamp\\TCP\\GlobeLampTCPFlood_1.pcap',
#  './1-Flood\\Globe Lamp\\TCP\\GlobeLampTCPFlood_2.pcap',
#  './1-Flood\\Globe Lamp\\TCP\\GlobeLampTCPFlood_3.pcap',
#  './1-Flood\\Globe Lamp\\UDP\\GlobeLampUDPFlood_1.pcap',
#  './1-Flood\\Globe Lamp\\UDP\\GlobeLampUDPFlood_2.pcap',
#  './1-Flood\\Globe Lamp\\UDP\\GlobeLampUDPFlood_3.pcap',
#  './1-Flood\\Gosund Plug - Roomba\\HTTP\\GosundRoombaHTTPFlood_1.pcap',
#  './1-Flood\\Gosund Plug - Roomba\\HTTP\\GosundRoombaHTTPFlood_2.pcap',
#  './1-Flood\\Gosund Plug - Roomba\\HTTP\\GosundRoombaHTTPFlood_3.pcap',
#  './1-Flood\\Gosund Plug - Roomba\\TCP\\GosundRoombaTCPFlood_1.pcap',
#  './1-Flood\\Gosund Plug - Roomba\\TCP\\GosundRoombaTCPFlood_2.pcap',
#  './1-Flood\\Gosund Plug - Roomba\\TCP\\GosundRoombaTCPFlood_3.pcap',
#  './1-Flood\\Gosund Plug - Roomba\\UDP\\GosundRoombaUDPFlood_1.pcap',
#  './1-Flood\\Gosund Plug - Roomba\\UDP\\GosundRoombaUDPFlood_2.pcap',
#  './1-Flood\\Gosund Plug - Roomba\\UDP\\GosundRoombaUDPFlood_3.pcap',
#  './1-Flood\\HeimVision Camera\\TCP\\HeimVisionCamTCPFlood_1.pcap',
#  './1-Flood\\HeimVision Camera\\TCP\\HeimVisionCamTCPFlood_2.pcap',
#  './1-Flood\\HeimVision Camera\\TCP\\HeimVisionCamTCPFlood_3.pcap',
#  './1-Flood\\HeimVision Camera\\UDP\\HeimVisionCamUDPFlood_1.pcap',
#  './1-Flood\\HeimVision Camera\\UDP\\HeimVisionCamUDPFlood_2.pcap',
#  './1-Flood\\HeimVision Camera\\UDP\\HeimVisionCamUDPFlood_3.pcap',
#  './1-Flood\\Netatmo Camera\\TCP\\NetatmoCamTCPFlood_1.pcap',
#  './1-Flood\\Netatmo Camera\\TCP\\NetatmoCamTCPFlood_2.pcap',
#  './1-Flood\\Netatmo Camera\\TCP\\NetatmoCamTCPFlood_3.pcap',
#  './1-Flood\\Netatmo Camera\\UDP\\NetatmoCamUDPFlood_1.pcap',
#  './1-Flood\\Netatmo Camera\\UDP\\NetatmoCamUDPFlood_2.pcap',
#  './1-Flood\\Netatmo Camera\\UDP\\NetatmoCamUDPFlood_3.pcap',
#  './1-Flood\\Philips Hue Bridge\\TCP\\PhilipsHueTCPFlood_1.pcap',
#  './1-Flood\\Philips Hue Bridge\\TCP\\PhilipsHueTCPFlood_2.pcap',
#  './1-Flood\\Philips Hue Bridge\\TCP\\PhilipsHueTCPFlood_3.pcap',
#  './1-Flood\\Philips Hue Bridge\\UDP\\PhilipsHueUDPFlood_1.pcap',
#  './1-Flood\\Philips Hue Bridge\\UDP\\PhilipsHueUDPFlood_2.pcap',
#  './1-Flood\\Philips Hue Bridge\\UDP\\PhilipsHueUDPFlood_3.pcap',
#  './1-Flood\\Ring Basestation\\HTTP\\RingBaseStationHTTPFlood_1.pcap',
#  './1-Flood\\Ring Basestation\\HTTP\\RingBaseStationHTTPFlood_2.pcap',
#  './1-Flood\\Ring Basestation\\HTTP\\RingBaseStationHTTPFlood_3.pcap',
#  './1-Flood\\Ring Basestation\\TCP\\RingBaseStationTCPFlood_1.pcap',
#  './1-Flood\\Ring Basestation\\TCP\\RingBaseStationTCPFlood_2.pcap',
#  './1-Flood\\Ring Basestation\\TCP\\RingBaseStationTCPFlood_3.pcap',
#  './1-Flood\\Ring Basestation\\UDP\\RingBaseStationUDPFlood_1.pcap',
#  './1-Flood\\Ring Basestation\\UDP\\RingBaseStationUDPFlood_2.pcap',
#  './1-Flood\\Ring Basestation\\UDP\\RingBaseStationUDPFlood_3.pcap',
#  './1-Flood\\SimCam\\TCP\\simcamTCPFlood_1.pcap',
#  './1-Flood\\SimCam\\TCP\\simcamTCPFlood_2.pcap',
#  './1-Flood\\SimCam\\TCP\\simcamTCPFlood_3.pcap',
#  './2-RTSP Brute Force\\Hydra\\Amcrest Camera\\AmcrestCamBruteForce_1.pcap',
#  './2-RTSP Brute Force\\Hydra\\Amcrest Camera\\AmcrestCamBruteForce_2.pcap',
#  './2-RTSP Brute Force\\Hydra\\Amcrest Camera\\AmcrestCamBruteForce_3.pcap',
#  './2-RTSP Brute Force\\Hydra\\SimCam\\SimcamBruteForce_1.pcap',
#  './2-RTSP Brute Force\\Hydra\\SimCam\\SimcamBruteForce_2.pcap',
#  './2-RTSP Brute Force\\Hydra\\SimCam\\SimcamBruteForce_3.pcap',
#  './2-RTSP Brute Force\\Nmap\\Amcrest Camera\\AmcrestCamRTSP_1.pcap',
#  './2-RTSP Brute Force\\Nmap\\Amcrest Camera\\AmcrestCamRTSP_2.pcap',
#  './2-RTSP Brute Force\\Nmap\\Amcrest Camera\\AmcrestCamRTSP_3.pcap',
#  './2-RTSP Brute Force\\Nmap\\HeimVision Camera\\HeimVisionCamRTSP_1.pcap',
#  './2-RTSP Brute Force\\Nmap\\HeimVision Camera\\HeimVisionCamRTSP_2.pcap',
#  './2-RTSP Brute Force\\Nmap\\HeimVision Camera\\HeimVisionCamRTSP_3.pcap',
#  './2-RTSP Brute Force\\Nmap\\Luohe Camera\\LuoheCamRSTP_1.pcap',
#  './2-RTSP Brute Force\\Nmap\\Luohe Camera\\LuoheCamRSTP_2.pcap',
#  './2-RTSP Brute Force\\Nmap\\Luohe Camera\\LuoheCamRSTP_3.pcap',
#  './2-RTSP Brute Force\\Nmap\\SimCam\\SIMCAMRTSP_1.pcap',
#  './2-RTSP Brute Force\\Nmap\\SimCam\\SIMCAMRTSP_2.pcap']

# %%
for i in files_add:
    temp=i[4:]
    temp=temp.replace(" ","_")
    temp=temp.replace("\\","-")
    temp=f"./pcaps/{temp}"
    os.rename(i,temp)
    print(temp)
# Out:
# ./pcaps/Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_1.pcap
# ./pcaps/Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_2.pcap
# ./pcaps/Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_3.pcap
# ./pcaps/Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_1.pcap
# ./pcaps/Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_2.pcap
# ./pcaps/Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_3.pcap
# ./pcaps/Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_1.pcap
# ./pcaps/Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_2.pcap
# ./pcaps/Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_3.pcap
# ./pcaps/Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_1.pcap
# ./pcaps/Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_2.pcap
# ./pcaps/Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_3.pcap
# ./pcaps/Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_1.pcap
# ./pcaps/Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_2.pcap
# ./pcaps/Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_3.pcap
# ./pcaps/Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_1.pcap
# ./pcaps/Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_2.pcap
# ./pcaps/Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_3.pcap
# ./pcaps/Flood-Borun_Camera-UDP-BorunCamUDPFlood_1.pcap
# ./pcaps/Flood-Borun_Camera-UDP-BorunCamUDPFlood_2.pcap
# ./pcaps/Flood-Borun_Camera-UDP-BorunCamUDPFlood_3.pcap
# ./pcaps/Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_1.pcap
# ./pcaps/Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_2.pcap
# ./pcaps/Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_3.pcap
# ./pcaps/Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_1.pcap
# ./pcaps/Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_2.pcap
# ./pcaps/Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_3.pcap
# ./pcaps/Flood-Eufy_Home_Base-UDP-EufyHomeBaseUDPFlood_1.pcap
# ./pcaps/Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_1.pcap
# ./pcaps/Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_2.pcap
# ./pcaps/Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_3.pcap
# ./pcaps/Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_1.pcap
# ./pcaps/Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_2.pcap
# ./pcaps/Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_3.pcap
# ./pcaps/Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_1.pcap
# ./pcaps/Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_2.pcap
# ./pcaps/Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_3.pcap
# ./pcaps/Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_1.pcap
# ./pcaps/Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_2.pcap
# ./pcaps/Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_3.pcap
# ./pcaps/Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_1.pcap
# ./pcaps/Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_2.pcap
# ./pcaps/Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_3.pcap
# ./pcaps/Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_1.pcap
# ./pcaps/Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_2.pcap
# ./pcaps/Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_3.pcap
# ./pcaps/Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_1.pcap
# ./pcaps/Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_2.pcap
# ./pcaps/Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_3.pcap
# ./pcaps/Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_1.pcap
# ./pcaps/Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_2.pcap
# ./pcaps/Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_3.pcap
# ./pcaps/Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_1.pcap
# ./pcaps/Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_2.pcap
# ./pcaps/Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_3.pcap
# ./pcaps/Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_1.pcap
# ./pcaps/Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_2.pcap
# ./pcaps/Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_3.pcap
# ./pcaps/Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_1.pcap
# ./pcaps/Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_2.pcap
# ./pcaps/Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_3.pcap
# ./pcaps/Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_1.pcap
# ./pcaps/Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_2.pcap
# ./pcaps/Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_3.pcap
# ./pcaps/Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_1.pcap
# ./pcaps/Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_2.pcap
# ./pcaps/Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_3.pcap
# ./pcaps/Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_1.pcap
# ./pcaps/Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_2.pcap
# ./pcaps/Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_3.pcap
# ./pcaps/Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_1.pcap
# ./pcaps/Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_2.pcap
# ./pcaps/Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_3.pcap
# ./pcaps/Flood-SimCam-TCP-simcamTCPFlood_1.pcap
# ./pcaps/Flood-SimCam-TCP-simcamTCPFlood_2.pcap
# ./pcaps/Flood-SimCam-TCP-simcamTCPFlood_3.pcap
# ./pcaps/RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_1.pcap
# ./pcaps/RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_2.pcap
# ./pcaps/RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_3.pcap
# ./pcaps/RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_1.pcap
# ./pcaps/RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_2.pcap
# ./pcaps/RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_3.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_1.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_2.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_3.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_1.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_2.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_3.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_1.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_2.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_3.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_1.pcap
# ./pcaps/RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_2.pcap

# %%
files_add=find_the_way('./','.pcap')
uzun=len(files_add)
uzun
# Out:
# 93

# %%
df = pd.read_csv( "dataset_description.csv")
df
# Out:
#     No                                          File Name          Category  \
# 0    1   Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_1.pcap             Flood
# 1    2   Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_2.pcap             Flood
# 2    3   Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_3.pcap             Flood
# 3    4     Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_1.pcap             Flood
# 4    5     Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_2.pcap             Flood
# ..  ..                                                ...               ...
# 88  89  RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRST...  RTSP Brute Force
# 89  90  RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRST...  RTSP Brute Force
# 90  91  RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRST...  RTSP Brute Force
# 91  92     RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_1.pcap  RTSP Brute Force
# 92  93     RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_2.pcap  RTSP Brute Force
#
#    Sub-category                                               Rule
# 0          HTTP  ip.src == 192.168.137.5 or ip.src ==192.168.13...
# 1          HTTP  ip.src == 192.168.137.5 or ip.src ==192.168.13...
# 2          HTTP  ip.src == 192.168.137.5 or ip.src ==192.168.13...
# 3           TCP  ip.src == 192.168.137.5 or ip.src ==192.168.13...
# 4           TCP  ip.src == 192.168.137.5 or ip.src ==192.168.13...
# ..          ...                                                ...
# 88         Nmap  ip.src == 192.168.137.5 or ip.src ==192.168.13...
# 89         Nmap  ip.src == 192.168.137.5 or ip.src ==192.168.13...
# 90         Nmap  ip.src == 192.168.137.5 or ip.src ==192.168.13...
# 91         Nmap  ip.src == 192.168.137.5 or ip.src ==192.168.13...
# 92         Nmap  ip.src == 192.168.137.5 or ip.src ==192.168.13...
#
# [93 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['No', 'File Name', 'Category', 'Sub-category', 'Rule'], dtype='object')

# %%
name=df['File Name']
rule=df['Rule']
cat=df['Category']
subcat=df['Sub-category']

# %%
name
# Out:
# 0      Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_1.pcap
# 1      Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_2.pcap
# 2      Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_3.pcap
# 3        Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_1.pcap
# 4        Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_2.pcap
#                             ...
# 88    RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRST...
# 89    RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRST...
# 90    RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRST...
# 91       RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_1.pcap
# 92       RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_2.pcap
# Name: File Name, Length: 93, dtype: object

# %%
for i in range(len(name)):
    add=str(cat[i])+"@"+str(subcat[i])+"_"
    add=add.replace(" ","_")
    command='tshark -Y \"'+str(rule[i])+"\" -r ./pcaps/"+str(name[i])+" -T fields -e frame.number > ./pcaps/attack_"+str(name[i])[:-4]+"csv"
    os.system(command)
    command='tshark -Y \"!('+str(rule[i])+")\" -r ./pcaps/"+str(name[i])+" -T fields -e frame.number > ./pcaps/normal_"+str(name[i])[:-4]+"csv"
    os.system(command)
    files_add=find_the_way('./','.pcap')
    if uzun==len(files_add):    
        print(command,"\n")
    uzun=len(files_add)
# Out:
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Borun_Camera-UDP-BorunCamUDPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Borun_Camera-UDP-BorunCamUDPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Borun_Camera-UDP-BorunCamUDPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Borun_Camera-UDP-BorunCamUDPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Borun_Camera-UDP-BorunCamUDPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Borun_Camera-UDP-BorunCamUDPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Eufy_Home_Base-UDP-EufyHomeBaseUDPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Eufy_Home_Base-UDP-EufyHomeBaseUDPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_3.csv
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_2.csv
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-SimCam-TCP-simcamTCPFlood_1.pcap -T fields -e frame.number > ./pcaps/normal_Flood-SimCam-TCP-simcamTCPFlood_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-SimCam-TCP-simcamTCPFlood_2.pcap -T fields -e frame.number > ./pcaps/normal_Flood-SimCam-TCP-simcamTCPFlood_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/Flood-SimCam-TCP-simcamTCPFlood_3.pcap -T fields -e frame.number > ./pcaps/normal_Flood-SimCam-TCP-simcamTCPFlood_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_1.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_2.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_3.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_1.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_2.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_3.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_1.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_2.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_3.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_1.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_2.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_3.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_1.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_2.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_2.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_3.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_3.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_1.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_1.csv
#
# tshark -Y "!(ip.src == 192.168.137.5 or ip.src ==192.168.137.246)" -r ./pcaps/RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_2.pcap -T fields -e frame.number > ./pcaps/normal_RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_2.csv

# %% [markdown]
# # MERGE CSVS

# %%
name_list=find_the_way('./pcaps','.csv')

# %%
label_files=[]
for i in name_list:
    temp=i[15:]
    if temp not in label_files:
        label_files.append(temp)

# %%
for i in label_files:

    name=find_the_way('./pcaps',i)
    print(name)

    dfA = pd.read_csv(name[0], header=None)
    dfA=dfA.rename(columns={0: "PacketNumber"})
    dfA["Label"]=[1] * len(dfA)
    
    
    dfN = pd.read_csv(name[1], header=None)
    dfN=dfN.rename(columns={0: "PacketNumber"})    
    dfN["Label"]=[0] * len(dfN) 

    df = pd.concat([dfA,dfN])
    df=df.sort_values('PacketNumber')
    df.to_csv(f"./pcaps/{i}",  index=False)
    print(i,df.groupby("Label").size(),"\n\n\n")
    os.remove(f"./pcaps\\normal_{i}")
    os.remove(f"./pcaps\\attack_{i}")
# Out:
# ['./pcaps\\attack_Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_1.csv', './pcaps\\normal_Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_1.csv']
# Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_1.csv Label
# 0    35190
# 1    35264
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_2.csv', './pcaps\\normal_Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_2.csv']
# Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_2.csv Label
# 0    114932
# 1    115117
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_3.csv', './pcaps\\normal_Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_3.csv']
# Flood-ArloQ_Camera-HTTP-ArloQCamHTTPFlood_3.csv Label
# 0    115626
# 1    116045
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_1.csv', './pcaps\\normal_Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_1.csv']
# Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_1.csv Label
# 0    1004
# 1    1003
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_2.csv', './pcaps\\normal_Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_2.csv']
# Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_2.csv Label
# 0    1009
# 1    1001
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_3.csv', './pcaps\\normal_Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_3.csv']
# Flood-ArloQ_Camera-TCP-ArloQCamTCPFlood_3.csv Label
# 0    1007
# 1    1002
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_1.csv', './pcaps\\normal_Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_1.csv']
# Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_1.csv Label
# 0        15
# 1    800829
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_2.csv', './pcaps\\normal_Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_2.csv']
# Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_2.csv Label
# 0        14
# 1    800857
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_3.csv', './pcaps\\normal_Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_3.csv']
# Flood-ArloQ_Camera-UDP-ArloQCamUDPFlood_3.csv Label
# 0         6
# 1    288405
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_1.csv', './pcaps\\normal_Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_1.csv']
# Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_1.csv Label
# 0    32331
# 1    32398
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_2.csv', './pcaps\\normal_Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_2.csv']
# Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_2.csv Label
# 0    42326
# 1    42397
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_3.csv', './pcaps\\normal_Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_3.csv']
# Flood-Atomi_Coffee_Maker-HTTP-AtomiCoffeeMakerHTTPFlood_3.csv Label
# 0    42522
# 1    42634
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_1.csv', './pcaps\\normal_Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_1.csv']
# Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_1.csv Label
# 0    2047
# 1    2020
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_2.csv', './pcaps\\normal_Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_2.csv']
# Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_2.csv Label
# 0    2036
# 1    2013
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_3.csv', './pcaps\\normal_Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_3.csv']
# Flood-Atomi_Coffee_Maker-TCP-AtomiCoffeeMakerTCPFlood_3.csv Label
# 0    2037
# 1    2016
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_1.csv', './pcaps\\normal_Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_1.csv']
# Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_1.csv Label
# 0         27
# 1    1001366
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_2.csv', './pcaps\\normal_Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_2.csv']
# Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_2.csv Label
# 0        27
# 1    984138
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_3.csv', './pcaps\\normal_Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_3.csv']
# Flood-Atomi_Coffee_Maker-UDP-AtomiCoffeeMakerUDPFlood_3.csv Label
# 0        33
# 1    773722
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Borun_Camera-UDP-BorunCamUDPFlood_1.csv', './pcaps\\normal_Flood-Borun_Camera-UDP-BorunCamUDPFlood_1.csv']
# Flood-Borun_Camera-UDP-BorunCamUDPFlood_1.csv Label
# 0        24
# 1    926701
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Borun_Camera-UDP-BorunCamUDPFlood_2.csv', './pcaps\\normal_Flood-Borun_Camera-UDP-BorunCamUDPFlood_2.csv']
# Flood-Borun_Camera-UDP-BorunCamUDPFlood_2.csv Label
# 0        25
# 1    806861
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Borun_Camera-UDP-BorunCamUDPFlood_3.csv', './pcaps\\normal_Flood-Borun_Camera-UDP-BorunCamUDPFlood_3.csv']
# Flood-Borun_Camera-UDP-BorunCamUDPFlood_3.csv Label
# 0        30
# 1    950712
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_1.csv', './pcaps\\normal_Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_1.csv']
# Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_1.csv Label
# 0       3
# 1    3006
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_2.csv', './pcaps\\normal_Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_2.csv']
# Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_2.csv Label
# 0      14
# 1    3293
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_3.csv', './pcaps\\normal_Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_3.csv']
# Flood-Eufy_Home_Base-HTTP-EufyHomeBaseHTTPFlood_3.csv Label
# 0      12
# 1    3032
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_1.csv', './pcaps\\normal_Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_1.csv']
# Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_1.csv Label
# 0       4
# 1    3012
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_2.csv', './pcaps\\normal_Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_2.csv']
# Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_2.csv Label
# 0      10
# 1    3371
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_3.csv', './pcaps\\normal_Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_3.csv']
# Flood-Eufy_Home_Base-TCP-EufyHomeBaseTCPFlood_3.csv Label
# 0       4
# 1    2906
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Eufy_Home_Base-UDP-EufyHomeBaseUDPFlood_1.csv', './pcaps\\normal_Flood-Eufy_Home_Base-UDP-EufyHomeBaseUDPFlood_1.csv']
# Flood-Eufy_Home_Base-UDP-EufyHomeBaseUDPFlood_1.csv Label
# 0        12
# 1    585251
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_1.csv', './pcaps\\normal_Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_1.csv']
# Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_1.csv Label
# 0    8726
# 1    9120
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_2.csv', './pcaps\\normal_Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_2.csv']
# Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_2.csv Label
# 0    14702
# 1    15686
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_3.csv', './pcaps\\normal_Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_3.csv']
# Flood-Globe_Lamp-HTTP-GlobeLampHTTPFlood_3.csv Label
# 0    14774
# 1    15708
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_1.csv', './pcaps\\normal_Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_1.csv']
# Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_1.csv Label
# 0    2039
# 1    2092
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_2.csv', './pcaps\\normal_Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_2.csv']
# Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_2.csv Label
# 0    2043
# 1    2044
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_3.csv', './pcaps\\normal_Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_3.csv']
# Flood-Globe_Lamp-TCP-GlobeLampTCPFlood_3.csv Label
# 0    2046
# 1    2043
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_1.csv', './pcaps\\normal_Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_1.csv']
# Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_1.csv Label
# 0         8
# 1    997333
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_2.csv', './pcaps\\normal_Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_2.csv']
# Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_2.csv Label
# 0        14
# 1    851487
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_3.csv', './pcaps\\normal_Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_3.csv']
# Flood-Globe_Lamp-UDP-GlobeLampUDPFlood_3.csv Label
# 0        18
# 1    883031
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_1.csv', './pcaps\\normal_Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_1.csv']
# Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_1.csv Label
# 0    24688
# 1    24707
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_2.csv', './pcaps\\normal_Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_2.csv']
# Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_2.csv Label
# 0    4498
# 1    4499
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_3.csv', './pcaps\\normal_Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_3.csv']
# Flood-Gosund_Plug_-_Roomba-HTTP-GosundRoombaHTTPFlood_3.csv Label
# 0    9776
# 1    9838
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_1.csv', './pcaps\\normal_Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_1.csv']
# Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_1.csv Label
# 0    26
# 1    13
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_2.csv', './pcaps\\normal_Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_2.csv']
# Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_2.csv Label
# 0    1014
# 1    1001
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_3.csv', './pcaps\\normal_Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_3.csv']
# Flood-Gosund_Plug_-_Roomba-TCP-GosundRoombaTCPFlood_3.csv Label
# 0    1019
# 1    1001
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_1.csv', './pcaps\\normal_Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_1.csv']
# Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_1.csv Label
# 0         12
# 1    1044248
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_2.csv', './pcaps\\normal_Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_2.csv']
# Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_2.csv Label
# 0        11
# 1    794245
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_3.csv', './pcaps\\normal_Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_3.csv']
# Flood-Gosund_Plug_-_Roomba-UDP-GosundRoombaUDPFlood_3.csv Label
# 0         13
# 1    1007600
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_1.csv', './pcaps\\normal_Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_1.csv']
# Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_1.csv Label
# 0    14687
# 1    28679
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_2.csv', './pcaps\\normal_Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_2.csv']
# Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_2.csv Label
# 0     4913
# 1    11999
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_3.csv', './pcaps\\normal_Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_3.csv']
# Flood-HeimVision_Camera-TCP-HeimVisionCamTCPFlood_3.csv Label
# 0    11416
# 1    20006
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_1.csv', './pcaps\\normal_Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_1.csv']
# Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_1.csv Label
# 0        17
# 1    930135
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_2.csv', './pcaps\\normal_Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_2.csv']
# Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_2.csv Label
# 0         29
# 1    1039396
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_3.csv', './pcaps\\normal_Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_3.csv']
# Flood-HeimVision_Camera-UDP-HeimVisionCamUDPFlood_3.csv Label
# 0         20
# 1    1021871
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_1.csv', './pcaps\\normal_Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_1.csv']
# Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_1.csv Label
# 0    24269
# 1    69151
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_2.csv', './pcaps\\normal_Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_2.csv']
# Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_2.csv Label
# 0    22026
# 1    67248
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_3.csv', './pcaps\\normal_Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_3.csv']
# Flood-Netatmo_Camera-TCP-NetatmoCamTCPFlood_3.csv Label
# 0    21696
# 1    59003
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_1.csv', './pcaps\\normal_Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_1.csv']
# Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_1.csv Label
# 0        20
# 1    738017
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_2.csv', './pcaps\\normal_Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_2.csv']
# Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_2.csv Label
# 0        19
# 1    915728
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_3.csv', './pcaps\\normal_Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_3.csv']
# Flood-Netatmo_Camera-UDP-NetatmoCamUDPFlood_3.csv Label
# 0        26
# 1    867931
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_1.csv', './pcaps\\normal_Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_1.csv']
# Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_1.csv Label
# 0    302880
# 1    519519
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_2.csv', './pcaps\\normal_Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_2.csv']
# Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_2.csv Label
# 0    292299
# 1    506563
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_3.csv', './pcaps\\normal_Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_3.csv']
# Flood-Philips_Hue_Bridge-TCP-PhilipsHueTCPFlood_3.csv Label
# 0    297544
# 1    454303
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_1.csv', './pcaps\\normal_Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_1.csv']
# Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_1.csv Label
# 0         9
# 1    815546
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_2.csv', './pcaps\\normal_Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_2.csv']
# Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_2.csv Label
# 0         2
# 1    788343
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_3.csv', './pcaps\\normal_Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_3.csv']
# Flood-Philips_Hue_Bridge-UDP-PhilipsHueUDPFlood_3.csv Label
# 0         2
# 1    993514
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_1.csv', './pcaps\\normal_Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_1.csv']
# Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_1.csv Label
# 0    8564
# 1    8559
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_2.csv', './pcaps\\normal_Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_2.csv']
# Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_2.csv Label
# 0    14699
# 1    14714
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_3.csv', './pcaps\\normal_Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_3.csv']
# Flood-Ring_Basestation-HTTP-RingBaseStationHTTPFlood_3.csv Label
# 0    14805
# 1    14833
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_1.csv', './pcaps\\normal_Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_1.csv']
# Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_1.csv Label
# 0    1004
# 1    1001
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_2.csv', './pcaps\\normal_Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_2.csv']
# Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_2.csv Label
# 0    1009
# 1    1001
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_3.csv', './pcaps\\normal_Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_3.csv']
# Flood-Ring_Basestation-TCP-RingBaseStationTCPFlood_3.csv Label
# 0    1007
# 1    1004
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_1.csv', './pcaps\\normal_Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_1.csv']
# Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_1.csv Label
# 0          8
# 1    1389849
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_2.csv', './pcaps\\normal_Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_2.csv']
# Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_2.csv Label
# 0        15
# 1    951508
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_3.csv', './pcaps\\normal_Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_3.csv']
# Flood-Ring_Basestation-UDP-RingBaseStationUDPFlood_3.csv Label
# 0         8
# 1    855992
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-SimCam-TCP-simcamTCPFlood_1.csv', './pcaps\\normal_Flood-SimCam-TCP-simcamTCPFlood_1.csv']
# Flood-SimCam-TCP-simcamTCPFlood_1.csv Label
# 0    136260
# 1    224724
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-SimCam-TCP-simcamTCPFlood_2.csv', './pcaps\\normal_Flood-SimCam-TCP-simcamTCPFlood_2.csv']
# Flood-SimCam-TCP-simcamTCPFlood_2.csv Label
# 0     89420
# 1    152435
# dtype: int64
#
#
#
# ['./pcaps\\attack_Flood-SimCam-TCP-simcamTCPFlood_3.csv', './pcaps\\normal_Flood-SimCam-TCP-simcamTCPFlood_3.csv']
# Flood-SimCam-TCP-simcamTCPFlood_3.csv Label
# 0    104296
# 1    178678
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_1.csv', './pcaps\\normal_RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_1.csv']
# RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_1.csv Label
# 0    261
# 1    312
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_2.csv', './pcaps\\normal_RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_2.csv']
# RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_2.csv Label
# 0    265
# 1    315
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_3.csv', './pcaps\\normal_RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_3.csv']
# RTSP_Brute_Force-Hydra-Amcrest_Camera-AmcrestCamBruteForce_3.csv Label
# 0    266
# 1    318
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_1.csv', './pcaps\\normal_RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_1.csv']
# RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_1.csv Label
# 0     7318
# 1    14434
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_2.csv', './pcaps\\normal_RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_2.csv']
# RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_2.csv Label
# 0     7144
# 1    14235
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_3.csv', './pcaps\\normal_RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_3.csv']
# RTSP_Brute_Force-Hydra-SimCam-SimcamBruteForce_3.csv Label
# 0     7179
# 1    14372
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_1.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_1.csv']
# RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_1.csv Label
# 0    15589
# 1     2411
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_2.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_2.csv']
# RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_2.csv Label
# 0    15311
# 1     2200
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_3.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_3.csv']
# RTSP_Brute_Force-Nmap-Amcrest_Camera-AmcrestCamRTSP_3.csv Label
# 0    15187
# 1     2202
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_1.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_1.csv']
# RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_1.csv Label
# 0    3575
# 1    2173
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_2.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_2.csv']
# RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_2.csv Label
# 0    3485
# 1    2184
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_3.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_3.csv']
# RTSP_Brute_Force-Nmap-HeimVision_Camera-HeimVisionCamRTSP_3.csv Label
# 0    3486
# 1    2193
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_1.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_1.csv']
# RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_1.csv Label
# 0    9642
# 1    2332
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_2.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_2.csv']
# RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_2.csv Label
# 0    7860
# 1     179
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_3.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_3.csv']
# RTSP_Brute_Force-Nmap-Luohe_Camera-LuoheCamRSTP_3.csv Label
# 0    9697
# 1    2372
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_1.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_1.csv']
# RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_1.csv Label
# 0    17428
# 1     2178
# dtype: int64
#
#
#
# ['./pcaps\\attack_RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_2.csv', './pcaps\\normal_RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_2.csv']
# RTSP_Brute_Force-Nmap-SimCam-SIMCAMRTSP_2.csv Label
# 0    17393
# 1     2174
# dtype: int64

# %%
# !shutdown /s /t 36
