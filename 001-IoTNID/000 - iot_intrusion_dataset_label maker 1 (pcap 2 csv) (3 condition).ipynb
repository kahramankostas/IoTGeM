# %%
import os
import pandas as pd

# %%
def find_the_way(path,file_format,con=""):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                if con in file:
                    files_add.append(os.path.join(r, file))  
            
    return files_add

# %%
def folder(f_name): #this function creates a folder named "attacks" in the program directory.
    try:
        if not os.path.exists(f_name):
            os.makedirs(f_name)
    except OSError:
        print ("The folder could not be created!")

# %%
folder("./pcaps/csvs")
folder("./pcaps/labelled")

# %%
files_add=find_the_way('./pcaps','.pcap')
uzun=len(files_add)
uzun
# Out:
# 41

# %%
df = pd.read_csv( "dataset_description.csv")
df
# Out:
#     No                        File Name                  Category  \
# 0    2      mitm-arpspoofing-1-dec.pcap  Man in the Middle (MITM)
# 1    3      mitm-arpspoofing-2-dec.pcap  Man in the Middle (MITM)
# 2    4      mitm-arpspoofing-3-dec.pcap  Man in the Middle (MITM)
# 3    5      mitm-arpspoofing-4-dec.pcap  Man in the Middle (MITM)
# 4    6      mitm-arpspoofing-5-dec.pcap  Man in the Middle (MITM)
# 5    7      mitm-arpspoofing-6-dec.pcap  Man in the Middle (MITM)
# 6    8       dos-synflooding-1-dec.pcap   Denial of Service (DoS)
# 7    9       dos-synflooding-2-dec.pcap   Denial of Service (DoS)
# 8   10       dos-synflooding-3-dec.pcap   Denial of Service (DoS)
# 9   11       dos-synflooding-4-dec.pcap   Denial of Service (DoS)
# 10  12       dos-synflooding-5-dec.pcap   Denial of Service (DoS)
# 11  13       dos-synflooding-6-dec.pcap   Denial of Service (DoS)
# 12  14         scan-hostport-1-dec.pcap                  Scanning
# 13  15         scan-hostport-1-dec.pcap                  Scanning
# 14  16         scan-hostport-2-dec.pcap                  Scanning
# 15  17         scan-hostport-2-dec.pcap                  Scanning
# 16  18         scan-hostport-3-dec.pcap                  Scanning
# 17  19         scan-hostport-3-dec.pcap                  Scanning
# 18  20         scan-hostport-4-dec.pcap                  Scanning
# 19  21         scan-hostport-4-dec.pcap                  Scanning
# 20  22         scan-hostport-5-dec.pcap                  Scanning
# 21  23         scan-hostport-5-dec.pcap                  Scanning
# 22  24         scan-hostport-6-dec.pcap                  Scanning
# 23  25         scan-hostport-6-dec.pcap                  Scanning
# 24  26           scan-portos-1-dec.pcap                  Scanning
# 25  27           scan-portos-1-dec.pcap                  Scanning
# 26  28           scan-portos-2-dec.pcap                  Scanning
# 27  29           scan-portos-2-dec.pcap                  Scanning
# 28  30           scan-portos-3-dec.pcap                  Scanning
# 29  31           scan-portos-3-dec.pcap                  Scanning
# 30  32           scan-portos-4-dec.pcap                  Scanning
# 31  33           scan-portos-4-dec.pcap                  Scanning
# 32  34           scan-portos-5-dec.pcap                  Scanning
# 33  35           scan-portos-5-dec.pcap                  Scanning
# 34  36           scan-portos-6-dec.pcap                  Scanning
# 35  37           scan-portos-6-dec.pcap                  Scanning
# 36  38     mirai-udpflooding-1-dec.pcap              Mirai Botnet
# 37  39     mirai-udpflooding-2-dec.pcap              Mirai Botnet
# 38  40     mirai-udpflooding-3-dec.pcap              Mirai Botnet
# 39  41     mirai-udpflooding-4-dec.pcap              Mirai Botnet
# 40  42     mirai-ackflooding-1-dec.pcap              Mirai Botnet
# 41  43     mirai-ackflooding-2-dec.pcap              Mirai Botnet
# 42  44     mirai-ackflooding-3-dec.pcap              Mirai Botnet
# 43  45     mirai-ackflooding-4-dec.pcap              Mirai Botnet
# 44  46    mirai-httpflooding-1-dec.pcap              Mirai Botnet
# 45  47    mirai-httpflooding-2-dec.pcap              Mirai Botnet
# 46  48    mirai-httpflooding-3-dec.pcap              Mirai Botnet
# 47  49    mirai-httpflooding-4-dec.pcap              Mirai Botnet
# 48  50  mirai-hostbruteforce-1-dec.pcap              Mirai Botnet
# 49  51  mirai-hostbruteforce-1-dec.pcap              Mirai Botnet
# 50  52  mirai-hostbruteforce-2-dec.pcap              Mirai Botnet
# 51  53  mirai-hostbruteforce-2-dec.pcap              Mirai Botnet
# 52  54  mirai-hostbruteforce-3-dec.pcap              Mirai Botnet
# 53  55  mirai-hostbruteforce-3-dec.pcap              Mirai Botnet
# 54  56  mirai-hostbruteforce-4-dec.pcap              Mirai Botnet
# 55  57  mirai-hostbruteforce-4-dec.pcap              Mirai Botnet
# 56  58  mirai-hostbruteforce-5-dec.pcap              Mirai Botnet
# 57  59  mirai-hostbruteforce-5-dec.pcap              Mirai Botnet
#
#             Sub-category                                               Rule
# 0           ARP Spoofing  eth.addr == f0:18:98:5e:ff:9f and  ((((ip.src ...
# 1           ARP Spoofing  eth.addr == f0:18:98:5e:ff:9f and  ((((ip.src ...
# 2           ARP Spoofing  eth.addr == f0:18:98:5e:ff:9f and  ((((ip.src ...
# 3           ARP Spoofing  eth.addr == f0:18:98:5e:ff:9f and  (((ip.addr ...
# 4           ARP Spoofing  eth.addr == f0:18:98:5e:ff:9f and  (((ip.addr ...
# 5           ARP Spoofing  eth.addr == f0:18:98:5e:ff:9f and  (((ip.addr ...
# 6           SYN Flooding  ip.src == 222.0.0.0/8 and tcp.flags.syn == 1 a...
# 7           SYN Flooding  ip.src == 222.0.0.0/8 and tcp.flags.syn == 1 a...
# 8           SYN Flooding  ip.src == 111.0.0.0/8 and tcp.flags.syn == 1 a...
# 9           SYN Flooding  ip.dst == 192.168.0.24 and tcp.flags.syn == 1 ...
# 10          SYN Flooding  ip.dst == 192.168.0.24 and tcp.flags.syn == 1 ...
# 11          SYN Flooding  ip.dst == 192.168.0.24 and tcp.flags.syn == 1 ...
# 12        Host Discovery  (eth.src == f0:18:98:5e:ff:9f and arp and eth....
# 13         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 14        Host Discovery  (eth.src == f0:18:98:5e:ff:9f and arp and eth....
# 15         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 16        Host Discovery  (eth.src == f0:18:98:5e:ff:9f and arp and eth....
# 17         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 18        Host Discovery  (eth.src == f0:18:98:5e:ff:9f and arp and eth....
# 19         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 20        Host Discovery  (eth.src == f0:18:98:5e:ff:9f and arp and eth....
# 21         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 22        Host Discovery  (eth.src == f0:18:98:5e:ff:9f and arp and eth....
# 23         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 24         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 25  OS-Version Detection  (ip.src == 192.168.0.15 and ip.dst == 192.168....
# 26         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 27  OS-Version Detection  (ip.src == 192.168.0.15 and ip.dst == 192.168....
# 28         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 29  OS-Version Detection  (ip.src == 192.168.0.15 and ip.dst == 192.168....
# 30         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 31  OS-Version Detection  (ip.src == 192.168.0.15 and ip.dst == 192.168....
# 32         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 33  OS-Version Detection  (ip.src == 192.168.0.15 and ip.dst == 192.168....
# 34         Port Scanning  ip.src == 192.168.0.15 and ip.dst == 192.168.0...
# 35  OS-Version Detection  (ip.src == 192.168.0.15 and ip.dst == 192.168....
# 36          UDP Flooding                            ip.dst == 210.89.164.90
# 37          UDP Flooding                            ip.dst == 210.89.164.90
# 38          UDP Flooding                            ip.dst == 210.89.164.90
# 39          UDP Flooding                            ip.dst == 210.89.164.90
# 40          ACK Flooding                            ip.dst == 210.89.164.90
# 41          ACK Flooding                            ip.dst == 210.89.164.90
# 42          ACK Flooding                            ip.dst == 210.89.164.90
# 43          ACK Flooding                            ip.dst == 210.89.164.90
# 44         HTTP Flooding                            ip.dst == 210.89.164.90
# 45         HTTP Flooding                            ip.dst == 210.89.164.90
# 46         HTTP Flooding                            ip.dst == 210.89.164.90
# 47         HTTP Flooding                            ip.dst == 210.89.164.90
# 48        Host Discovery  arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.s...
# 49     Telnet Bruteforce           tcp.dstport==23 and ip.src==192.168.0.13
# 50        Host Discovery  arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.s...
# 51     Telnet Bruteforce           tcp.dstport==23 and ip.src==192.168.0.24
# 52        Host Discovery  arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.s...
# 53     Telnet Bruteforce           tcp.dstport==23 and ip.src==192.168.0.13
# 54        Host Discovery  arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.s...
# 55     Telnet Bruteforce           tcp.dstport==23 and ip.src==192.168.0.24
# 56        Host Discovery  arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.s...
# 57     Telnet Bruteforce           tcp.dstport==23 and ip.src==192.168.0.13

# %%
files = {}
for i in df["File Name"].values:
    files[i] = files.get(i, 0) + 1
files
# Out:
# {'mitm-arpspoofing-1-dec.pcap': 1,
#  'mitm-arpspoofing-2-dec.pcap': 1,
#  'mitm-arpspoofing-3-dec.pcap': 1,
#  'mitm-arpspoofing-4-dec.pcap': 1,
#  'mitm-arpspoofing-5-dec.pcap': 1,
#  'mitm-arpspoofing-6-dec.pcap': 1,
#  'dos-synflooding-1-dec.pcap': 1,
#  'dos-synflooding-2-dec.pcap': 1,
#  'dos-synflooding-3-dec.pcap': 1,
#  'dos-synflooding-4-dec.pcap': 1,
#  'dos-synflooding-5-dec.pcap': 1,
#  'dos-synflooding-6-dec.pcap': 1,
#  'scan-hostport-1-dec.pcap': 2,
#  'scan-hostport-2-dec.pcap': 2,
#  'scan-hostport-3-dec.pcap': 2,
#  'scan-hostport-4-dec.pcap': 2,
#  'scan-hostport-5-dec.pcap': 2,
#  'scan-hostport-6-dec.pcap': 2,
#  'scan-portos-1-dec.pcap': 2,
#  'scan-portos-2-dec.pcap': 2,
#  'scan-portos-3-dec.pcap': 2,
#  'scan-portos-4-dec.pcap': 2,
#  'scan-portos-5-dec.pcap': 2,
#  'scan-portos-6-dec.pcap': 2,
#  'mirai-udpflooding-1-dec.pcap': 1,
#  'mirai-udpflooding-2-dec.pcap': 1,
#  'mirai-udpflooding-3-dec.pcap': 1,
#  'mirai-udpflooding-4-dec.pcap': 1,
#  'mirai-ackflooding-1-dec.pcap': 1,
#  'mirai-ackflooding-2-dec.pcap': 1,
#  'mirai-ackflooding-3-dec.pcap': 1,
#  'mirai-ackflooding-4-dec.pcap': 1,
#  'mirai-httpflooding-1-dec.pcap': 1,
#  'mirai-httpflooding-2-dec.pcap': 1,
#  'mirai-httpflooding-3-dec.pcap': 1,
#  'mirai-httpflooding-4-dec.pcap': 1,
#  'mirai-hostbruteforce-1-dec.pcap': 2,
#  'mirai-hostbruteforce-2-dec.pcap': 2,
#  'mirai-hostbruteforce-3-dec.pcap': 2,
#  'mirai-hostbruteforce-4-dec.pcap': 2,
#  'mirai-hostbruteforce-5-dec.pcap': 2}

# %%
normal_rules={}
for i in files:
    if (files[i])>1:
        print(i)
        temp=df[df["File Name"]==i].values
        rule=f"!({temp[0][4]}) && !({temp[1][4]})"
        normal_rules[i]=rule
# Out:
# scan-hostport-1-dec.pcap
# scan-hostport-2-dec.pcap
# scan-hostport-3-dec.pcap
# scan-hostport-4-dec.pcap
# scan-hostport-5-dec.pcap
# scan-hostport-6-dec.pcap
# scan-portos-1-dec.pcap
# scan-portos-2-dec.pcap
# scan-portos-3-dec.pcap
# scan-portos-4-dec.pcap
# scan-portos-5-dec.pcap
# scan-portos-6-dec.pcap
# mirai-hostbruteforce-1-dec.pcap
# mirai-hostbruteforce-2-dec.pcap
# mirai-hostbruteforce-3-dec.pcap
# mirai-hostbruteforce-4-dec.pcap
# mirai-hostbruteforce-5-dec.pcap

# %%
normal_rules
# Out:
# {'scan-hostport-1-dec.pcap': '!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 13000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))',
#  'scan-hostport-2-dec.pcap': '!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 14500) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))',
#  'scan-hostport-3-dec.pcap': '!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 2000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))',
#  'scan-hostport-4-dec.pcap': '!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 4000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))',
#  'scan-hostport-5-dec.pcap': '!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 1300) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))',
#  'scan-hostport-6-dec.pcap': '!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 1000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))',
#  'scan-portos-1-dec.pcap': '!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.13) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))',
#  'scan-portos-2-dec.pcap': '!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.13) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))',
#  'scan-portos-3-dec.pcap': '!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.13) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))',
#  'scan-portos-4-dec.pcap': '!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.24) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))',
#  'scan-portos-5-dec.pcap': '!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.24) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))',
#  'scan-portos-6-dec.pcap': '!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.24) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))',
#  'mirai-hostbruteforce-1-dec.pcap': '!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.13 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.13)',
#  'mirai-hostbruteforce-2-dec.pcap': '!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.24 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.24)',
#  'mirai-hostbruteforce-3-dec.pcap': '!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.13 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.13)',
#  'mirai-hostbruteforce-4-dec.pcap': '!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.24 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.24)',
#  'mirai-hostbruteforce-5-dec.pcap': '!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.13 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.13)'}

# %%
df.columns
# Out:
# Index(['No', 'File Name', 'Category', 'Sub-category', 'Rule'], dtype='object')

# %%
name=df['File Name']
rule=df['Rule']
cat=df['Category']
subcat=df['Sub-category']

# %%
subcat
# Out:
# 0             ARP Spoofing
# 1             ARP Spoofing
# 2             ARP Spoofing
# 3             ARP Spoofing
# 4             ARP Spoofing
# 5             ARP Spoofing
# 6             SYN Flooding
# 7             SYN Flooding
# 8             SYN Flooding
# 9             SYN Flooding
# 10            SYN Flooding
# 11            SYN Flooding
# 12          Host Discovery
# 13           Port Scanning
# 14          Host Discovery
# 15           Port Scanning
# 16          Host Discovery
# 17           Port Scanning
# 18          Host Discovery
# 19           Port Scanning
# 20          Host Discovery
# 21           Port Scanning
# 22          Host Discovery
# 23           Port Scanning
# 24           Port Scanning
# 25    OS-Version Detection
# 26           Port Scanning
# 27    OS-Version Detection
# 28           Port Scanning
# 29    OS-Version Detection
# 30           Port Scanning
# 31    OS-Version Detection
# 32           Port Scanning
# 33    OS-Version Detection
# 34           Port Scanning
# 35    OS-Version Detection
# 36            UDP Flooding
# 37            UDP Flooding
# 38            UDP Flooding
# 39            UDP Flooding
# 40            ACK Flooding
# 41            ACK Flooding
# 42            ACK Flooding
# 43            ACK Flooding
# 44           HTTP Flooding
# 45           HTTP Flooding
# 46           HTTP Flooding
# 47           HTTP Flooding
# 48          Host Discovery
# 49       Telnet Bruteforce
# 50          Host Discovery
# 51       Telnet Bruteforce
# 52          Host Discovery
# 53       Telnet Bruteforce
# 54          Host Discovery
# 55       Telnet Bruteforce
# 56          Host Discovery
# 57       Telnet Bruteforce
# Name: Sub-category, dtype: object

# %%
for i in range(len(name)):
    output=str(name[i])[:-5]+"_"+str(subcat[i])+".csv"
    output=output.replace(" ","-")
    print(output)
    if files[name[i]]==1:
        add=str(cat[i])+"@"+str(subcat[i])+"_"
        add=add.replace(" ","_")
        command='tshark -Y \"'+str(rule[i])+"\" -r ./pcaps/"+str(name[i])+f" -T fields -e frame.number > ./pcaps/attack_"+output
        os.system(command)
        command='tshark -Y \"!('+str(rule[i])+")\" -r ./pcaps/"+str(name[i])+f" -T fields -e frame.number > ./pcaps/normal_"+output
        os.system(command)
        files_add=find_the_way('./','.pcap')
        if uzun==len(files_add):    
            print(command,"\n")
        uzun=len(files_add) 
    else:
        add=str(cat[i])+"@"+str(subcat[i])+"_"
        add=add.replace(" ","_")
        command='tshark -Y \"'+str(rule[i])+"\" -r ./pcaps/"+str(name[i])+f" -T fields -e frame.number > ./pcaps/attack_"+output
        os.system(command)
        command='tshark -Y \"'+str(normal_rules[name[i]])+"\" -r ./pcaps/"+str(name[i])+f" -T fields -e frame.number > ./pcaps/normal_"+output
        os.system(command)
        files_add=find_the_way('./','.pcap')
        if uzun==len(files_add):    
            print(command,"\n")
        uzun=len(files_add)
# Out:
# mitm-arpspoofing-1-dec_ARP-Spoofing.csv
# tshark -Y "!(eth.addr == f0:18:98:5e:ff:9f and  ((((ip.src == 192.168.0.16 and ip.dst == 192.168.0.13)  or (ip.src == 192.168.0.13 and ip.dst == 192.168.0.16))  and !icmp and tcp)  or (arp.src.hw_mac == f0:18:98:5e:ff:9f  and (arp.dst.hw_mac == bc:1c:81:4b:ae:ba or arp.dst.hw_mac == 48:4b:aa:2c:d8:f9))) )" -r ./pcaps/mitm-arpspoofing-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_mitm-arpspoofing-1-dec_ARP-Spoofing.csv
#
# mitm-arpspoofing-2-dec_ARP-Spoofing.csv
# tshark -Y "!(eth.addr == f0:18:98:5e:ff:9f and  ((((ip.src == 192.168.0.16 and ip.dst == 192.168.0.13)  or (ip.src == 192.168.0.13 and ip.dst == 192.168.0.16))  and !icmp and tcp)  or (arp.src.hw_mac == f0:18:98:5e:ff:9f  and (arp.dst.hw_mac == bc:1c:81:4b:ae:ba or arp.dst.hw_mac == 48:4b:aa:2c:d8:f9))) )" -r ./pcaps/mitm-arpspoofing-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_mitm-arpspoofing-2-dec_ARP-Spoofing.csv
#
# mitm-arpspoofing-3-dec_ARP-Spoofing.csv
# tshark -Y "!(eth.addr == f0:18:98:5e:ff:9f and  ((((ip.src == 192.168.0.16 and ip.dst == 192.168.0.13)  or (ip.src == 192.168.0.13 and ip.dst == 192.168.0.16))  and !icmp and tcp)  or (arp.src.hw_mac == f0:18:98:5e:ff:9f  and (arp.dst.hw_mac == bc:1c:81:4b:ae:ba or arp.dst.hw_mac == 48:4b:aa:2c:d8:f9))) )" -r ./pcaps/mitm-arpspoofing-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_mitm-arpspoofing-3-dec_ARP-Spoofing.csv
#
# mitm-arpspoofing-4-dec_ARP-Spoofing.csv
# tshark -Y "!(eth.addr == f0:18:98:5e:ff:9f and  (((ip.addr == 192.168.0.24)  and !icmp and tcp)  or (arp.src.hw_mac == f0:18:98:5e:ff:9f  and (arp.dst.hw_mac == 04:32:f4:45:17:b3 or arp.dst.hw_mac == 88:36:6c:d7:1c:56))) )" -r ./pcaps/mitm-arpspoofing-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_mitm-arpspoofing-4-dec_ARP-Spoofing.csv
#
# mitm-arpspoofing-5-dec_ARP-Spoofing.csv
# tshark -Y "!(eth.addr == f0:18:98:5e:ff:9f and  (((ip.addr == 192.168.0.24)  and !icmp and tcp)  or (arp.src.hw_mac == f0:18:98:5e:ff:9f  and (arp.dst.hw_mac == 04:32:f4:45:17:b3 or arp.dst.hw_mac == 88:36:6c:d7:1c:56))) )" -r ./pcaps/mitm-arpspoofing-5-dec.pcap -T fields -e frame.number > ./pcaps/normal_mitm-arpspoofing-5-dec_ARP-Spoofing.csv
#
# mitm-arpspoofing-6-dec_ARP-Spoofing.csv
# tshark -Y "!(eth.addr == f0:18:98:5e:ff:9f and  (((ip.addr == 192.168.0.24)  and !icmp and tcp)  or (arp.src.hw_mac == f0:18:98:5e:ff:9f  and (arp.dst.hw_mac == 04:32:f4:45:17:b3 or arp.dst.hw_mac == 88:36:6c:d7:1c:56))) )" -r ./pcaps/mitm-arpspoofing-6-dec.pcap -T fields -e frame.number > ./pcaps/normal_mitm-arpspoofing-6-dec_ARP-Spoofing.csv
#
# dos-synflooding-1-dec_SYN-Flooding.csv
# tshark -Y "!(ip.src == 222.0.0.0/8 and tcp.flags.syn == 1 and ip.dst == 192.168.0.13 and tcp.dstport == 554 and tcp)" -r ./pcaps/dos-synflooding-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-1-dec_SYN-Flooding.csv
#
# dos-synflooding-2-dec_SYN-Flooding.csv
# tshark -Y "!(ip.src == 222.0.0.0/8 and tcp.flags.syn == 1 and ip.dst == 192.168.0.13 and tcp.dstport == 554 and tcp)" -r ./pcaps/dos-synflooding-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-2-dec_SYN-Flooding.csv
#
# dos-synflooding-3-dec_SYN-Flooding.csv
# tshark -Y "!(ip.src == 111.0.0.0/8 and tcp.flags.syn == 1 and ip.dst == 192.168.0.13 and tcp.dstport == 554 and tcp)" -r ./pcaps/dos-synflooding-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-3-dec_SYN-Flooding.csv
#
# dos-synflooding-4-dec_SYN-Flooding.csv
# tshark -Y "!(ip.dst == 192.168.0.24 and tcp.flags.syn == 1 and ip.src == 111.0.0.0/8 and tcp and tcp.dstport == 19604)" -r ./pcaps/dos-synflooding-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-4-dec_SYN-Flooding.csv
#
# dos-synflooding-5-dec_SYN-Flooding.csv
# tshark -Y "!(ip.dst == 192.168.0.24 and tcp.flags.syn == 1 and ip.src == 111.0.0.0/8 and tcp and tcp.dstport == 19604)" -r ./pcaps/dos-synflooding-5-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-5-dec_SYN-Flooding.csv
#
# dos-synflooding-6-dec_SYN-Flooding.csv
# tshark -Y "!(ip.dst == 192.168.0.24 and tcp.flags.syn == 1 and ip.src == 111.0.0.0/8 and tcp and tcp.dstport == 19604)" -r ./pcaps/dos-synflooding-6-dec.pcap -T fields -e frame.number > ./pcaps/normal_dos-synflooding-6-dec_SYN-Flooding.csv
#
# scan-hostport-1-dec_Host-Discovery.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 13000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-1-dec_Host-Discovery.csv
#
# scan-hostport-1-dec_Port-Scanning.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 13000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-1-dec_Port-Scanning.csv
#
# scan-hostport-2-dec_Host-Discovery.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 14500) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-2-dec_Host-Discovery.csv
#
# scan-hostport-2-dec_Port-Scanning.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 14500) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-2-dec_Port-Scanning.csv
#
# scan-hostport-3-dec_Host-Discovery.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 2000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-3-dec_Host-Discovery.csv
#
# scan-hostport-3-dec_Port-Scanning.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 2000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-3-dec_Port-Scanning.csv
#
# scan-hostport-4-dec_Host-Discovery.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 4000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-4-dec_Host-Discovery.csv
#
# scan-hostport-4-dec_Port-Scanning.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 4000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-4-dec_Port-Scanning.csv
#
# scan-hostport-5-dec_Host-Discovery.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 1300) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-5-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-5-dec_Host-Discovery.csv
#
# scan-hostport-5-dec_Port-Scanning.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 1300) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-5-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-5-dec_Port-Scanning.csv
#
# scan-hostport-6-dec_Host-Discovery.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 1000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-6-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-6-dec_Host-Discovery.csv
#
# scan-hostport-6-dec_Port-Scanning.csv
# tshark -Y "!((eth.src == f0:18:98:5e:ff:9f and arp and eth.dst == ff:ff:ff:ff:ff:ff) and frame.number < 1000) && !(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1))" -r ./pcaps/scan-hostport-6-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-hostport-6-dec_Port-Scanning.csv
#
# scan-portos-1-dec_Port-Scanning.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.13) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-1-dec_Port-Scanning.csv
#
# scan-portos-1-dec_OS-Version-Detection.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.13) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-1-dec_OS-Version-Detection.csv
#
# scan-portos-2-dec_Port-Scanning.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.13) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-2-dec_Port-Scanning.csv
#
# scan-portos-2-dec_OS-Version-Detection.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.13) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-2-dec_OS-Version-Detection.csv
#
# scan-portos-3-dec_Port-Scanning.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.13) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-3-dec_Port-Scanning.csv
#
# scan-portos-3-dec_OS-Version-Detection.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.13) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.13 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-3-dec_OS-Version-Detection.csv
#
# scan-portos-4-dec_Port-Scanning.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.24) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-4-dec_Port-Scanning.csv
#
# scan-portos-4-dec_OS-Version-Detection.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.24) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-4-dec_OS-Version-Detection.csv
#
# scan-portos-5-dec_Port-Scanning.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.24) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-5-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-5-dec_Port-Scanning.csv
#
# scan-portos-5-dec_OS-Version-Detection.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.24) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-5-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-5-dec_OS-Version-Detection.csv
#
# scan-portos-6-dec_Port-Scanning.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.24) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-6-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-6-dec_Port-Scanning.csv
#
# scan-portos-6-dec_OS-Version-Detection.csv
# tshark -Y "!(ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)) && !((ip.src == 192.168.0.15 and ip.dst == 192.168.0.24) and (not icmp) and not (ip.src == 192.168.0.15 and ip.dst == 192.168.0.24 and ((tcp.flags.syn == 1 and tcp.window_size == 1024) or tcp.flags.reset == 1)))" -r ./pcaps/scan-portos-6-dec.pcap -T fields -e frame.number > ./pcaps/normal_scan-portos-6-dec_OS-Version-Detection.csv
#
# mirai-udpflooding-1-dec_UDP-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-udpflooding-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-udpflooding-1-dec_UDP-Flooding.csv
#
# mirai-udpflooding-2-dec_UDP-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-udpflooding-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-udpflooding-2-dec_UDP-Flooding.csv
#
# mirai-udpflooding-3-dec_UDP-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-udpflooding-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-udpflooding-3-dec_UDP-Flooding.csv
#
# mirai-udpflooding-4-dec_UDP-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-udpflooding-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-udpflooding-4-dec_UDP-Flooding.csv
#
# mirai-ackflooding-1-dec_ACK-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-ackflooding-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-ackflooding-1-dec_ACK-Flooding.csv
#
# mirai-ackflooding-2-dec_ACK-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-ackflooding-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-ackflooding-2-dec_ACK-Flooding.csv
#
# mirai-ackflooding-3-dec_ACK-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-ackflooding-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-ackflooding-3-dec_ACK-Flooding.csv
#
# mirai-ackflooding-4-dec_ACK-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-ackflooding-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-ackflooding-4-dec_ACK-Flooding.csv
#
# mirai-httpflooding-1-dec_HTTP-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-httpflooding-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-httpflooding-1-dec_HTTP-Flooding.csv
#
# mirai-httpflooding-2-dec_HTTP-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-httpflooding-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-httpflooding-2-dec_HTTP-Flooding.csv
#
# mirai-httpflooding-3-dec_HTTP-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-httpflooding-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-httpflooding-3-dec_HTTP-Flooding.csv
#
# mirai-httpflooding-4-dec_HTTP-Flooding.csv
# tshark -Y "!(ip.dst == 210.89.164.90)" -r ./pcaps/mirai-httpflooding-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-httpflooding-4-dec_HTTP-Flooding.csv
#
# mirai-hostbruteforce-1-dec_Host-Discovery.csv
# tshark -Y "!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.13 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.13)" -r ./pcaps/mirai-hostbruteforce-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-hostbruteforce-1-dec_Host-Discovery.csv
#
# mirai-hostbruteforce-1-dec_Telnet-Bruteforce.csv
# tshark -Y "!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.13 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.13)" -r ./pcaps/mirai-hostbruteforce-1-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-hostbruteforce-1-dec_Telnet-Bruteforce.csv
#
# mirai-hostbruteforce-2-dec_Host-Discovery.csv
# tshark -Y "!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.24 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.24)" -r ./pcaps/mirai-hostbruteforce-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-hostbruteforce-2-dec_Host-Discovery.csv
#
# mirai-hostbruteforce-2-dec_Telnet-Bruteforce.csv
# tshark -Y "!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.24 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.24)" -r ./pcaps/mirai-hostbruteforce-2-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-hostbruteforce-2-dec_Telnet-Bruteforce.csv
#
# mirai-hostbruteforce-3-dec_Host-Discovery.csv
# tshark -Y "!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.13 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.13)" -r ./pcaps/mirai-hostbruteforce-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-hostbruteforce-3-dec_Host-Discovery.csv
#
# mirai-hostbruteforce-3-dec_Telnet-Bruteforce.csv
# tshark -Y "!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.13 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.13)" -r ./pcaps/mirai-hostbruteforce-3-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-hostbruteforce-3-dec_Telnet-Bruteforce.csv
#
# mirai-hostbruteforce-4-dec_Host-Discovery.csv
# tshark -Y "!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.24 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.24)" -r ./pcaps/mirai-hostbruteforce-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-hostbruteforce-4-dec_Host-Discovery.csv
#
# mirai-hostbruteforce-4-dec_Telnet-Bruteforce.csv
# tshark -Y "!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.24 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.24)" -r ./pcaps/mirai-hostbruteforce-4-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-hostbruteforce-4-dec_Telnet-Bruteforce.csv
#
# mirai-hostbruteforce-5-dec_Host-Discovery.csv
# tshark -Y "!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.13 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.13)" -r ./pcaps/mirai-hostbruteforce-5-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-hostbruteforce-5-dec_Host-Discovery.csv
#
# mirai-hostbruteforce-5-dec_Telnet-Bruteforce.csv
# tshark -Y "!(arp.dst.proto_ipv4 == 192.168.0.0/24 and arp.src.proto_ipv4 == 192.168.0.13 and eth.dst == ff:ff:ff:ff:ff:ff) && !(tcp.dstport==23 and ip.src==192.168.0.13)" -r ./pcaps/mirai-hostbruteforce-5-dec.pcap -T fields -e frame.number > ./pcaps/normal_mirai-hostbruteforce-5-dec_Telnet-Bruteforce.csv

# %%
name_list=find_the_way('./pcaps/','.csv')
for i in name_list:
    os.rename(i,i.replace("./pcaps",'./pcaps/csvs'))

# %% [markdown]
# # MERGE CSVS

# %%
def merger(name_list,name):
    flag=1
    df=pd.read_csv(name_list[0])
    col_names=list(df.columns)
    empty = pd.DataFrame(columns=col_names)
    empty.to_csv(name, mode="w", index=False)#,header=False)
    
    for i in name_list:
        if "normal" in i:
            if flag:
                df=pd.read_csv(i)
                df.to_csv(name, mode="a", index=False,header=False)
                df=pd.read_csv(name)
                flag=0
        else:
            df=pd.read_csv(i)
            df.to_csv(name, mode="a", index=False,header=False)
        
        
    df=pd.read_csv(name)
    df=df.sort_values('PacketNumber')
    df.to_csv(name,  index=False)

# %%
name_list=find_the_way('./pcaps/csvs/','.csv')
for i in name_list:
    if "normal" in i:
        label="Benign"
    else:
        temp=i[8:-4]
        label=temp.split("_")[2]
    
    df=pd.read_csv(i, names=["PacketNumber"], header=None)
    df["Label"]=len(df)*[label]
    df.to_csv(i,  index=False)

# %%
temp
# Out:
# 'csvs/attack_scan-portos-6-dec_Port-Scanning'

# %%
name_list=find_the_way('./pcaps','.csv')
for i in name_list:
    temp=i[8:-4]
    temp=temp.split("_")
    print(temp[1])
    name=f"./pcaps/labelled/{temp[1]}.csv"
    sub_list=find_the_way('./pcaps/csvs/',temp[1])
    merger(sub_list,name)
# Out:
# dos-synflooding-1-dec
# dos-synflooding-2-dec
# dos-synflooding-3-dec
# dos-synflooding-4-dec
# dos-synflooding-5-dec
# dos-synflooding-6-dec
# mirai-ackflooding-1-dec
# mirai-ackflooding-2-dec
# mirai-ackflooding-3-dec
# mirai-ackflooding-4-dec
# mirai-hostbruteforce-1-dec
# mirai-hostbruteforce-1-dec
# mirai-hostbruteforce-2-dec
# mirai-hostbruteforce-2-dec
# mirai-hostbruteforce-3-dec
# mirai-hostbruteforce-3-dec
# mirai-hostbruteforce-4-dec
# mirai-hostbruteforce-4-dec
# mirai-hostbruteforce-5-dec
# mirai-hostbruteforce-5-dec
# mirai-httpflooding-1-dec
# mirai-httpflooding-2-dec
# mirai-httpflooding-3-dec
# mirai-httpflooding-4-dec
# mirai-udpflooding-1-dec
# mirai-udpflooding-2-dec
# mirai-udpflooding-3-dec
# mirai-udpflooding-4-dec
# mitm-arpspoofing-1-dec
# mitm-arpspoofing-2-dec
# mitm-arpspoofing-3-dec
# mitm-arpspoofing-4-dec
# mitm-arpspoofing-5-dec
# mitm-arpspoofing-6-dec
# scan-hostport-1-dec
# scan-hostport-1-dec
# scan-hostport-2-dec
# scan-hostport-2-dec
# scan-hostport-3-dec
# scan-hostport-3-dec
# scan-hostport-4-dec
# scan-hostport-4-dec
# scan-hostport-5-dec
# scan-hostport-5-dec
# scan-hostport-6-dec
# scan-hostport-6-dec
# scan-portos-1-dec
# scan-portos-1-dec
# scan-portos-2-dec
# scan-portos-2-dec
# scan-portos-3-dec
# scan-portos-3-dec
# scan-portos-4-dec
# scan-portos-4-dec
# scan-portos-5-dec
# scan-portos-5-dec
# scan-portos-6-dec
# scan-portos-6-dec
# dos-synflooding-1-dec
# dos-synflooding-2-dec
# dos-synflooding-3-dec
# dos-synflooding-4-dec
# dos-synflooding-5-dec
# dos-synflooding-6-dec
# mirai-ackflooding-1-dec
# mirai-ackflooding-2-dec
# mirai-ackflooding-3-dec
# mirai-ackflooding-4-dec
# mirai-hostbruteforce-1-dec
# mirai-hostbruteforce-1-dec
# mirai-hostbruteforce-2-dec
# mirai-hostbruteforce-2-dec
# mirai-hostbruteforce-3-dec
# mirai-hostbruteforce-3-dec
# mirai-hostbruteforce-4-dec
# mirai-hostbruteforce-4-dec
# mirai-hostbruteforce-5-dec
# mirai-hostbruteforce-5-dec
# mirai-httpflooding-1-dec
# mirai-httpflooding-2-dec
# mirai-httpflooding-3-dec
# mirai-httpflooding-4-dec
# mirai-udpflooding-1-dec
# mirai-udpflooding-2-dec
# mirai-udpflooding-3-dec
# mirai-udpflooding-4-dec
# mitm-arpspoofing-1-dec
# mitm-arpspoofing-2-dec
# mitm-arpspoofing-3-dec
# mitm-arpspoofing-4-dec
# mitm-arpspoofing-5-dec
# mitm-arpspoofing-6-dec
# scan-hostport-1-dec
# scan-hostport-1-dec
# scan-hostport-2-dec
# scan-hostport-2-dec
# scan-hostport-3-dec
# scan-hostport-3-dec
# scan-hostport-4-dec
# scan-hostport-4-dec
# scan-hostport-5-dec
# scan-hostport-5-dec
# scan-hostport-6-dec
# scan-hostport-6-dec
# scan-portos-1-dec
# scan-portos-1-dec
# scan-portos-2-dec
# scan-portos-2-dec
# scan-portos-3-dec
# scan-portos-3-dec
# scan-portos-4-dec
# scan-portos-4-dec
# scan-portos-5-dec
# scan-portos-5-dec
# scan-portos-6-dec
# scan-portos-6-dec
